# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\iprak\Desktop\Py-DS-ML-Bootcamp-master\Refactored_Py_DS_ML_Bootcamp-master\TensorFlow_FILES\DATA\kc_house_data.csv")

# %%
# Data Exploration Starts

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
sns.set_style(style = "darkgrid")
sns.set_context("notebook")
# sns.set_context("poster")
plt.figure(figsize=(10,6))
sns.distplot(df["price"])

# %%
sns.countplot(df["bedrooms"])

# %%
df.corr()["price"].sort_values(ascending = False)
# Out:
# price            1.000000
# sqft_living      0.701917
# grade            0.667951
# sqft_above       0.605368
# sqft_living15    0.585241
# bathrooms        0.525906
# view             0.397370
# sqft_basement    0.323799
# bedrooms         0.308787
# lat              0.306692
# waterfront       0.266398
# floors           0.256804
# yr_renovated     0.126424
# sqft_lot         0.089876
# sqft_lot15       0.082845
# yr_built         0.053953
# condition        0.036056
# long             0.022036
# id              -0.016772
# zipcode         -0.053402
# Name: price, dtype: float64

# %%
sns.scatterplot(x = "price", y = "sqft_living", data = df)

# %%
plt.figure(figsize=(12, 9))
sns.boxplot(x = "bedrooms", y = "price", data = df)

# %%
plt.figure(figsize = (12,9))
sns.scatterplot(x = "price", y = "long", data = df)

# %%
plt.figure(figsize = (12,9))
sns.scatterplot(x = "price", y = "lat", data = df)

# %%
plt.figure(figsize = (14, 9))
sns.scatterplot(x = "long", y = "lat", data = df, hue = "price")

# %%
df.sort_values("price", ascending = False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)*0.01
# Out:
# 215.97

# %%
# dropping off top one percent of higher valued homes as their numbers are less
non_top_one_percent = df.sort_values("price", ascending = False).iloc[216:]

# %%
plt.figure(figsize = (14, 9))
sns.scatterplot(x = "long", y = "lat", data = non_top_one_percent, edgecolor = None, alpha = 0.2, palette = "RdYlGn", hue = "price")

# %%
plt.figure(figsize = (12,9))
sns.boxplot(x = "waterfront", y = "price", data = df)

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
# Feature Engineering Starts

# %%
df = df.drop("id", axis = 1)

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
df["date"]
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
df["year"] = df["date"].apply(lambda date: date.year)
df["month"] = df["date"].apply(lambda date: date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
plt.figure(figsize = (12,9))
sns.boxplot(x = "month", y = "price", data = df)

# %%
df.groupby("year").mean()["price"].sort_values(ascending = False)
# Out:
# year
# 2015    542279.005878
# 2014    539350.911777
# Name: price, dtype: float64

# %%
df.groupby("year").mean()["price"].plot()

# %%
df = df.drop("date", axis = 1)

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year', 'month'],
#       dtype='object')

# %%
df["zipcode"].value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
df = df.drop("zipcode", axis = 1)

# %%
df["sqft_basement"].value_counts().sort_values(ascending = False).head(20)
# Out:
# 0       13110
# 600       221
# 700       218
# 500       214
# 800       206
# 400       184
# 1000      149
# 900       144
# 300       142
# 200       108
# 530       107
# 480       106
# 750       105
# 450       103
# 720       102
# 620        91
# 580        85
# 840        85
# 420        81
# 860        80
# Name: sqft_basement, dtype: int64

# %%
sns.scatterplot(x = "sqft_basement", y = "price", data = df)

# %%
#  Scaling and Pre-processing Starts

# %%
X = df.drop("price", axis = 1)
y = df["price"].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (15117, 19)

# %%
model = Sequential()

model.add(Dense(19, activation = "relu"))
model.add(Dense(19, activation = "relu"))
model.add(Dense(19, activation = "relu"))
model.add(Dense(19, activation = "relu"))

model.add(Dense(1))

model.compile(optimizer = "adam", loss = "mse")

# %%
model.fit(x = X_train, y = y_train, 
          validation_data = (X_test, y_test), 
          batch_size = 128, epochs = 400)
# Out:
# Train on 15117 samples, validate on 6480 samples
# Epoch 1/400
# 15117/15117 [==============================] - 1s 69us/sample - loss: 430247368951.2448 - val_loss: 418952421355.7728
# Epoch 2/400
# 15117/15117 [==============================] - 0s 15us/sample - loss: 429375847823.7238 - val_loss: 415675536482.6074
# Epoch 3/400
# 15117/15117 [==============================] - 0s 15us/sample - loss: 414841677533.4026 - val_loss: 381361103636.8593
# Epoch 4/400
# 15117/15117 [==============================] - 0s 14us/sample - loss: 339714299505.2924 - val_loss: 258937217974.6765
# Epoch 5/400
# 15117/15117 [==============================] - 0s 14us/sample - loss: 187375344240.4117 - val_loss: 116781986226.8840
# Epoch 6/400
# 15117/15117 [==============================] - 0s 14us/sample - loss: 103951020324.3585 - val_loss: 95135182463.6839
# Epoch 7/400
# 15117/15117 [==============================] - 0s 14us/sample - loss: 97571042853.6964 - val_loss: 93712325442.3704
# Epoch 8/400
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score

# %%
predictions = model.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test, predictions))
# Out:
# 164808.70870689186

# %%
mean_absolute_error(y_test, predictions)
# Out:
# 102105.4804024402

# %%
df["price"].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
5.402966e+05
# Out:
# 540296.6

# %%
explained_variance_score(y_test, predictions)
# Out:
# 0.7952188041388084

# %%
plt.figure(figsize = (12,9))
plt.scatter(y_test, predictions)
plt.plot(y_test, y_test, "r")

# %%
single_house = df.drop("price", axis = 1).iloc[0]

# %%
single_house = scaler.transform(single_house.values.reshape(-1, 19))

# %%
model.predict(single_house)
# Out:
# array([[282817.56]], dtype=float32)

# %%
df.head(1)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3        1.0         1180      5650     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
#
#        lat     long  sqft_living15  sqft_lot15  year  month
# 0  47.5112 -122.257           1340        5650  2014     10
